# %% [markdown]
# # Lab 4: Problem set on Newton-Cotes formulas

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../styles/tma4215.css", "r").read()
    return HTML(styles)

# Comment out next line and execute this cell to restore the default notebook style 
#css_styling()

# %% [markdown]
# Inserting my secret latex macros here ...
# $$
# \DeclareMathOperator{\Div}{div}
# \DeclareMathOperator{\Grad}{grad}
# \DeclareMathOperator{\Curl}{curl}
# \DeclareMathOperator{\Rot}{rot}
# \DeclareMathOperator{\ord}{ord}
# \DeclareMathOperator{\Kern}{ker}
# \DeclareMathOperator{\Image}{im}
# \DeclareMathOperator{\spann}{span}
# \DeclareMathOperator{\rank}{rank}
# \DeclareMathOperator{\dist}{dist}
# \DeclareMathOperator{\diam}{diam}
# \DeclareMathOperator{\sig}{sig}
# \DeclareMathOperator{\Id}{Id}
# \DeclareMathOperator{\CQR}{CQR}
# \DeclareMathOperator{\QR}{QR}
# \DeclareMathOperator{\TR}{TR}
# \DeclareMathOperator{\CTR}{CTR}
# \DeclareMathOperator{\SR}{SR}
# \DeclareMathOperator{\CSR}{CSR}
# \DeclareMathOperator{\NCR}{NCR}
# \DeclareMathOperator{\MR}{MR}
# \newcommand{\RR}{\mathbb{R}}
# \newcommand{\NN}{\mathbb{N}}
# \newcommand{\VV}{\mathbb{V}}
# \newcommand{\dGamma}{\,\mathrm{d} \Gamma}
# \newcommand{\dGammah}{\,\mathrm{d} \Gamma_h}
# \newcommand{\dx}{\,\mathrm{d}x}
# \newcommand{\dy}{\,\mathrm{d}y}
# \newcommand{\ds}{\,\mathrm{d}s}
# \newcommand{\dt}{\,\mathrm{d}t}
# \newcommand{\dS}{\,\mathrm{d}S}
# \newcommand{\dV}{\,\mathrm{d}V}
# \newcommand{\dX}{\,\mathrm{d}X}
# \newcommand{\dY}{\,\mathrm{d}Y}
# \newcommand{\dE}{\,\mathrm{d}E}
# \newcommand{\dK}{\,\mathrm{d}K}
# \newcommand{\dM}{\,\mathrm{d}M}
# \newcommand{\cd}{\mathrm{cd}}
# \newcommand{\onehalf}{\frac{1}{2}}
# \newcommand{\bfP}{\boldsymbol P}
# \newcommand{\bfx}{\boldsymbol x}
# \newcommand{\bfy}{\boldsymbol y}
# \newcommand{\bfa}{\boldsymbol a}
# \newcommand{\bfu}{\boldsymbol u}
# \newcommand{\bfv}{\boldsymbol v}
# \newcommand{\bfe}{\boldsymbol e}
# \newcommand{\bfb}{\boldsymbol b}
# \newcommand{\bfc}{\boldsymbol c}
# \newcommand{\bfq}{\boldsymbol q}
# \newcommand{\bfy}{\boldsymbol y}
# \newcommand{\bff}{\boldsymbol f}
# \newcommand{\bfp}{\boldsymbol p}
# \newcommand{\bft}{\boldsymbol t}
# \newcommand{\bfj}{\boldsymbol j}
# \newcommand{\bfB}{\boldsymbol B}
# \newcommand{\bfV}{\boldsymbol V}
# \newcommand{\bfE}{\boldsymbol E}
# \newcommand{\bfB}{\boldsymbol B}
# \newcommand{\bfzero}{\boldsymbol 0}
# $$

# %% [markdown]
# The main task of this problem set is the following: for a given interval $(a,b)$ and $n+1$ equally distributed nodes $x_i = a + i \tfrac{(b-a)}{n}$
# for $i=0,\ldots n$, tabulate the weights for the Newton-Cotes formula up to $n=14$.
# The problem boils down to 2 task, namely
#
# 1. Defining the Lagrange polynomials $L_{in}$ for $i=0, \ldots, n$
# 2. Computing the weights $w_i = \int_a^b L_{in}(x) \dx$
#
# __Before you start:__ For the implementation of the task, we recommend to use the [sympy](https://docs.sympy.org/latest/index.html#) python module  for symbolic mathematics to perform tasks such as (symbolic) integration.
# Spend some time to browse  through the  [sympy tutorial](https://docs.sympy.org/latest/tutorial/index.html) and the [help on symbolic integration](https://docs.sympy.org/latest/modules/integrals/integrals.html). Using ```sympy```__Before you start:__ For the implementation of the task, we recommend to use the [sympy](https://docs.sympy.org/latest/index.html#) python module  for symbolic mathematics to perform tasks such as (symbolic) integration.
# Spend some time to browse  through the  [sympy tutorial](https://docs.sympy.org/latest/tutorial/index.html) and the [help on symbolic integration](https://docs.sympy.org/latest/modules/integrals/integrals.html). Using ```sympy``` you can for instance do something like this for $n=2$:

# %%
# import symbol x from sympy so that you can define symbolic functions of x
from sympy.abc import x
# import symbolic integration
from sympy import integrate, cos, N
import numpy as np
from functools import reduce
import pandas as pd
import mpmath
from collections import OrderedDict
# Define
a, b = 0, 1 
xqs = np.linspace(a,b,3)
# Define L_02 (not normalized)
L_02 = (x-xqs[1])*(x-xqs[2])
# Normalize it to satisfy l_02(x_0) = 1
L_02 = L_02/L_02.subs(x,xqs[0])

# Now integrate L_02 to compute the first weight
w_0 = integrate(L_02, (x, a, b))
print("w0 = {}".format(L_02))
print("w0 = {}".format(w_0))
# Out:
# w0 = 2.0*(x - 1.0)*(x - 0.5)
# w0 = 0.166666666666667

# %% [markdown]
# Of course,
# since you are asked to do comupute all $n+1$ weights  $n=1,\ldots,14$,
# you need to automatize the construction of the corresponding Lagrange polynoms.
# So proceed as follows

# %% [markdown]
# __a__) Write  a python function ```lagrange_polys``` which takes a list of $n+1$ quadrature points
# and returns a list of the corresponding $n+1$ Lagrange polynoms $\{L_{in}\}_{i=0}^n$
# defined a symbolic function using ```sympy```:

# %%
def lagrange_polys(xqs):
    n = len(xqs)
    Ls = []
    for k in range(n):
        num = 1
        denom = 1
        for i in range(n):
            if i != k:
                num *= (x - xqs[i])
                denom *= (xqs[k] - xqs[i])
        Ls.append(num/denom)
    return Ls

# Test the function
Lg_polys = lagrange_polys(xqs)
w_0 = integrate(Lg_polys[0], (x, a, b))
print("L_02 = {}".format(Lg_polys[0]))
print("w_0 = {0:.5f}".format(w_0))
# Out:
# L_02 = 2.0*(x - 1.0)*(x - 0.5)
# w_0 = 0.16667

# %% [markdown]
# __b__) Now the easy part! Employ your brand new ```def lagrange_polys``` function and implement a python function which takes as argument the desired degree of exactness $n$ and the interval end points
# $a,b$ and returns a list of quadrature points $\{x_i\}_{i=0}^n$ and quadrature weights $\{w_i\}_{i=0}^n$:

# %%
def newton_cotes_formula(n, a, b, chebyshev=False):
    xqs = np.linspace(a, b, n+1)
    if chebyshev:
        xqs = []
        for k in range(1, n+2):
            l = ((2*k-1)/(2*(n+2)))*np.pi
            xqs.append(0.5*(a+b)+0.5*(b-a)*np.cos(l))
    lg_polys = lagrange_polys(xqs)
    ws = [integrate(poly, (x, a, b)) for poly in lg_polys]
    return (xqs, ws)

# %% [markdown]
# __c__) Before you tabulate the quadrature weights with you newly implemented function, make sure that you implement them correctly. More, specifically, check for $n=1,\ldots 14$
# that the computed Newton-Cotes formula integrates polynomials up to order $n$ __exactly__.
#
# For $n$ is even, check that the corresponding Newton-Cotes rules even integrate polynomials up to order $n+1$  exactly (and not only up to $n$).
#
# Note:  Due to floating point related errors and some numerical instabilities when computing
# higher order Lagrange polynomials and integrals, the difference between the exact integral
# and the numerically error won't be 0, but around the machine precision for $n=1,2$ and then
# for each increase of the order $n$ you will roughly loose of significant digit in
# the difference between the two.
#
# It might be useful to implement a little function ```qr``` first,
# which takes $f$, $\{x_i\}_{i=0}^n$ and $\{w_i\}_{i=0}^n$ and
# applies the corresponding quadrature to compute $\int_a^b f\dx$ numerically.

# %%
def qr(f, poly_order, xqs, ws):
    qr_f = 0 
    for i in range(len(ws)):
        if f.__code__.co_argcount == 1: 
            qr_f += f(xqs[i])*ws[i]
        else:
            qr_f += f(xqs[i], poly_order)*ws[i]
    return qr_f

# %%
mono = lambda x,m: x**m

err_n = [None]
err_np1 = [None]
w = np.zeros((15,15))
for n in range(1, 15):
    args = newton_cotes_formula(n, a, b)
    err_n.append(integrate(mono(x, n), (x, a, b)) - qr(mono, n, *args))
    err_np1.append(integrate(mono(x, n + 1), (x, a, b)) - qr(mono, n + 1, *args))
    w[n-1][:] = args[1] + [0]*(14-n)


err_df = pd.DataFrame(OrderedDict({r'$E_n(x^n)$': err_n, r'$E_n(x^{n+1})$': err_np1, 
                       r'$E_n(x^n)-E_n(x^{n+1})$': np.subtract(err_n, err_np1, where=[False]+[True]*14)})) 
err_df
# Out:
#                $E_n(x^n)$         $E_n(x^{n+1})$ $E_n(x^n)-E_n(x^{n+1})$
# 0                    None                   None                    None
# 1                       0     -0.166666666666667       0.166666666666667
# 2                       0   2.77555756156289e-17   -2.77555756156289e-17
# 3    2.77555756156289e-16   -0.00370370370370343     0.00370370370370371
# 4    1.66533453693773e-16   1.66533453693773e-16                       0
# 5    1.72084568816899e-15  -0.000209523809522300    0.000209523809524020
# 6   -1.35447209004269e-14  -1.01030295240889e-14   -3.44169137633799e-15
# 7   -7.15538739370913e-14   -1.57719620408892e-5     1.57719619693353e-5
# 8    6.47121245478388e-14   4.19803081186387e-14    2.27318164292001e-14
# 9    1.88225823816168e-12   -1.37007446543436e-6     1.37007634769259e-6
# 10  -1.62923841084961e-12  -1.71711256324869e-12    8.78741523990811e-14
# 11  -4.31558261348997e-11   -1.29834741402490e-7     1.29791585576355e-7
# 12   1.13411918745143e-10   8.73309341509199e-11    2.60809845942234e-11
# 13    1.32113175954629e-9   -1.19536562454003e-8     1.32747880049466e-8
# 14  -7.13029593701897e-10  -7.28751170520070e-10    1.57215768181729e-11

# %% [markdown]
# We see that for even $n$ the Newton-Cotes rule integrate polynomials up to order $n+1$ exactly.

# %% [markdown]
# __d__) Tabulate the quadrature weights for the Newton-Cotes rule for $n=1,\ldots 14$. For which $n$  should you
# refrain from using the resulting quadrature rule (and why?)

# %%
pd.DataFrame(w)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.500000  0.500000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.166667  0.666667  0.166667  0.000000  0.000000  0.000000  0.000000
# 2   0.125000  0.375000  0.375000  0.125000  0.000000  0.000000  0.000000
# 3   0.077778  0.355556  0.133333  0.355556  0.077778  0.000000  0.000000
# 4   0.065972  0.260417  0.173611  0.173611  0.260417  0.065972  0.000000
# 5   0.048810  0.257143  0.032143  0.323810  0.032143  0.257143  0.048810
# 6   0.043461  0.207002  0.076562  0.172975  0.172975  0.076562  0.207002
# 7   0.034885  0.207690 -0.032734  0.370229 -0.160141  0.370229 -0.032734
# 8   0.031886  0.175681  0.012054  0.215893  0.064487  0.064487  0.215893
# 9   0.026834  0.177536 -0.081044  0.454946 -0.435155  0.713765 -0.435155
# 10  0.024933  0.154855 -0.037169  0.289658 -0.110178  0.177900  0.177900
# 11  0.021639  0.157036 -0.120322  0.566499 -0.816506  1.387760 -1.392213
# 12  0.020335  0.139876 -0.077712  0.387896 -0.376924  0.513676 -0.107147
# 13  0.018034  0.142088 -0.154025  0.699749 -1.323998  2.524078 -3.357865
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           7         8         9         10        11        12        13  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.043461  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.207690  0.034885  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.012054  0.175681  0.031886  0.000000  0.000000  0.000000  0.000000
# 9   0.454946 -0.081044  0.177536  0.026834  0.000000  0.000000  0.000000
# 10 -0.110178  0.289658 -0.037169  0.154855  0.024933  0.000000  0.000000
# 11  1.387760 -0.816506  0.566499 -0.120322  0.157036  0.021639  0.000000
# 12 -0.107147  0.513676 -0.376924  0.387896 -0.077712  0.139876  0.020335
# 13  3.903877 -3.357865  2.524078 -1.323998  0.699749 -0.154025  0.142088
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           14
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.018034
# 14  0.000000

# %% [markdown]
# The quadrature weights, $\{w_i\}_{i=0}^n$, for the Newton-Cotes rule for $n = 1,..., 14$ are seen in the output above.
# For $n=7$ and $n\geq 9$ we have negative quadrature weights, this can make the quadrature ill-conditioned, and the Newton-Cotes rule becomes practically useless for $n=7$ and $n\geq 9$

# %% [markdown]
# __e__) Finally, since we have all the nice machinery in place, we take a little extra-tour
# and investigate the convergence of the Newton-Cotes rules for $n\to \infty$.
#
# More precisely, compute for $f(x) = \cos(x)$ the integral $\int_{-4}^{5} f(x) \dx $ first analytically
# and then numerically using the Newton-Cotes rules for $n=1,\ldots, 14$ and tabulate
# the quadrature error $E_n(f) = \int_{-4}^{5} \cos(x)\dx - \NCR(\cos, n)$.
#
# Finally, repeat the same experiment for for $f(x) = \tfrac{1}{1+x^2}$.

# %%
f_cos = lambda x: cos(x)
f_frac = lambda x: 1/(1 + x**2)
a = -4
b = 5
err_cos = []
err_frac = []
np1 = 20
w_new = np.zeros((np1, np1))

for n in range(1, np1):
    args = newton_cotes_formula(n, a, b)
    q_cos = qr(f_cos, 1, *args)
    q_frac = qr(f_frac, 1, *args)
    if any(wi<0 for wi in args[1]):
        err_cos.append(None)
        err_frac.append(None)
    else:
        err_cos.append(N(integrate(f_cos(x), (x, a, b)) - q_cos, 20))
        err_frac.append(N(integrate(f_frac(x), (x, a, b)) - q_frac, 20))
    w_new[n-1] = args[1] + [0]*(np1-1-n)

errs_df = pd.DataFrame({r'$E_n\big(\cos(x)\big)$': err_cos, r'$E_n\bigg(\frac{1}{1+x^2}\bigg)$':err_frac})
errs_df.index += 1
errs_df
# Out:
#       $E_n\big(\cos(x)\big)$ $E_n\bigg(\frac{1}{1+x^2}\bigg)$
# 1   -0.050810310669331124067            2.2614356251831840735
# 2     -6.4262499882127245926           -2.2467091711969066173
# 3     -1.7185223641039987869           0.22727272925558260699
# 4      1.0183161502430125217           0.50970394767220149693
# 5     0.51827111772293870394           0.15675530325241592369
# 6    -0.12533837970124457052          -0.37132097678196730381
# 7   -0.073176252487377754796          -0.21459589706486127323
# 8                       None                             None
# 9   0.0065893125623362386215           0.15694095808557039309
# 10                      None                             None
# 11                      None                             None
# 12                      None                             None
# 13                      None                             None
# 14                      None                             None
# 15                      None                             None
# 16                      None                             None
# 17                      None                             None
# 18                      None                             None
# 19                      None                             None

# %% [markdown]
# When using polynomial interpolation with polynomials of high degree over a set of equidistant noes, we have oscillation at the edges of the interval, known as Runge's phenomenon. Increasing the order $n$, does not always increase the accuracy.
#
# Introduction of Chebyshev interpolation nodes will minimize the effect of Runge's phenomenon. The output below is from using Chebyshev interpolation nodes, and we see a slight improvement, but still some problems in approximating the integral for $f(x) = \frac{1}{1+x^2}$. In the case of negative weights, the error are displayed as $\texttt{None}$, for reasons mentioned in 1d). The use of Chebyshev nodes reduces the amount of negative weights, and we are able to use higher order terms without a ill-conditioned quadrature.

# %%
err_cos = []
err_frac = []
np1 = 20
w_new = np.zeros((np1, np1))
for n in range(1, np1):
    args = newton_cotes_formula(n, a, b, chebyshev=True)
    q_cos = qr(f_cos, 1, *args)
    q_frac = qr(f_frac, 1, *args)
    if any(wi<0 for wi in args[1]):
        err_cos.append(None)
        err_frac.append(None)
    else:
        err_cos.append(N(integrate(f_cos(x), (x, a, b)) - q_cos, 20))
        err_frac.append(N(integrate(f_frac(x), (x, a, b)) - q_frac, 20))
    w_new[n-1] = args[1] + [0]*(np1-1-n)

errs_df = pd.DataFrame({r'$E_n\big(\cos(x)\big)$': err_cos, r'$E_n\bigg(\frac{1}{1+x^2}\bigg)$':err_frac})
errs_df.index += 1
errs_df
# Out:
#         $E_n\big(\cos(x)\big)$ $E_n\bigg(\frac{1}{1+x^2}\bigg)$
# 1                         None                             None
# 2       -3.4311571256713592842          0.041131200837643312166
# 3        4.7062975219022911616            1.2720763752640168351
# 4        1.3633603383904680434           0.93468940503936691702
# 5       -1.0120483157740558039          -0.81363929758888499019
# 6      -0.19423663288568921715          -0.72501798686252184520
# 7                         None                             None
# 8      0.015164362690222302199           0.48882129175262033574
# 9    -0.0064532528704541264438          -0.13785745764106328490
# 10  -0.00074990393766878050660          -0.39811174049294940555
# 11                        None                             None
# 12  0.000025646971289863807288           0.23382952798366739647
# 13                        None                             None
# 14   -6.4340675071939930991e-7          -0.16081834711733001750
# 15    1.6774374205496026729e-7         -0.031670911298130054764
# 16    1.2196384172036646979e-8          0.092435134400871244690
# 17   -3.3365110202573025702e-9          0.039257431635163587384
# 18    1.4068563916603084854e-8         -0.053927113968151762254
# 19                        None                             None
